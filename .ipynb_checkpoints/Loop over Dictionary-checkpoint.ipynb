# %%
import json

# %%
f = open('credits_dict.json')
credits_dict = json.load(f)
print(credits_dict)
# Out:
# {'52fe49d29251416c750d4641': {'title': "Amblin'", 'release_date': '1968-12-18', 'job': 'Director'}, '61423cda5e1200008da45f31': {'title': "Amblin'", 'release_date': '1968-12-18', 'job': 'Editor'}, '52fe49d29251416c750d4647': {'title': "Amblin'", 'release_date': '1968-12-18', 'job': 'Writer'}, '5700afc4c3a3686e980049f1': {'title': 'Night Gallery', 'release_date': '1969-11-08', 'job': 'Director'}, '5967ba58c3a36879cb005d3f': {'title': 'LA 2017', 'release_date': '1971-01-15', 'job': 'Director'}, '52fe427ec3a36847f8023361': {'title': 'Duel', 'release_date': '1971-11-13', 'job': 'Director'}, '52fe49459251416c910a7f33': {'title': 'Something Evil', 'release_date': '1972-01-21', 'job': 'Director'}, '52fe4ae4c3a36847f81e7215': {'title': 'Savage', 'release_date': '1973-03-31', 'job': 'Director'}, '53b6ced90e0a2676bf0056e9': {'title': 'Ace Eli and Rodger of the Skies', 'release_date': '1973-03-31', 'job': 'Story'}, '52fe43f4c3a36847f807a475': {'title': 'The Sugarland Express', 'release_date': '
# ...

# %%
for id, credit in credits_dict.items():
    print(id, '\t', credit['title'])
# Out:
# 52fe49d29251416c750d4641 	 Amblin'
# 61423cda5e1200008da45f31 	 Amblin'
# 52fe49d29251416c750d4647 	 Amblin'
# 5700afc4c3a3686e980049f1 	 Night Gallery
# 5967ba58c3a36879cb005d3f 	 LA 2017
# 52fe427ec3a36847f8023361 	 Duel
# 52fe49459251416c910a7f33 	 Something Evil
# 52fe4ae4c3a36847f81e7215 	 Savage
# 53b6ced90e0a2676bf0056e9 	 Ace Eli and Rodger of the Skies
# 52fe43f4c3a36847f807a475 	 The Sugarland Express
# 52fe43f4c3a36847f807a4b3 	 The Sugarland Express
# 52fe4255c3a36847f801601f 	 Jaws
# 52fe427ec3a36847f8023453 	 Close Encounters of the Third Kind
# 52fe427fc3a36847f80234f7 	 Close Encounters of the Third Kind
# 5935a5b7c3a3685bf9000c36 	 I Wanna Hold Your Hand
# 52fe44509251416c750306d3 	 1941
# 5507dee8c3a3682b49000c84 	 Used Cars
# 52fe4215c3a36847f8002a01 	 Raiders of the Lost Ark
# 573afd4f925141150a000292 	 Continental Divide
# 52fe425dc3a36847f8018985 	 Poltergeist
# 52fe425dc3a36847f801896d 	 Poltergeist
# 55378046c3a36878fd0021ea 	 Poltergeist
# ...
